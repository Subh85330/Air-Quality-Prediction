# %%
import pandas as pd 
import numpy as np
df1 = pd.read_csv(r'E:\MTech\SEM1\Machine Learning\Assignment1\hourly_44201_2015\hourly_44201_2015.csv')
df2 = pd.read_csv(r'E:\MTech\SEM1\Machine Learning\Assignment1\AN142_2015.csv',skiprows=6,usecols=list(range(15)))
# Out:
# C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df2
# Out:
#      Station_ID             Date_Time pressure_set_1 air_temp_set_1  \
# 0           NaN                   NaN           INHG     Fahrenheit
# 1         AN142  01/01/2015 02:00 EST          29.47          32.92
# 2         AN142  01/01/2015 03:00 EST          29.47          32.02
# 3         AN142  01/01/2015 04:00 EST          29.47          31.66
# 4         AN142  01/01/2015 05:00 EST          29.44          31.12
# ...         ...                   ...            ...            ...
# 7929      AN142  12/31/2015 20:00 EST          16.18          50.92
# 7930      AN142  12/31/2015 21:00 EST          16.06          50.02
# 7931      AN142  12/31/2015 22:00 EST          15.98          49.12
# 7932      AN142  12/31/2015 23:00 EST          15.86          47.86
# 7933      AN142  01/01/2016 00:00 EST          15.86          47.86
#
#      relative_humidity_set_1 wind_speed_set_1 wind_direction_set_1  \
# 0                          %       Miles/hour              Degrees
# ...

# %%
df2[1:]['pressure_set_1'][pd.isnull(df2[1:]['pressure_set_1'])==True]
# Out:
# 7627    NaN
# 7628    NaN
# 7629    NaN
# 7630    NaN
# 7631    NaN
#        ...
# 7919    NaN
# 7920    NaN
# 7921    NaN
# 7926    NaN
# 7927    NaN
# Name: pressure_set_1, Length: 250, dtype: object

# %%
try:
    while list(df2[1:]['pressure_set_1']).index(np.NaN):
        temp=list(df2[1:]['pressure_set_1']).index(np.NaN)
        df2[1:]['pressure_set_1'][temp+1]=np.nanmean([
                                                       float(df2[1:]['pressure_set_1'][temp-1]),
                                                       float(df2[1:]['pressure_set_1'][temp]),
                                                       float(df2[1:]['pressure_set_1'][temp + 2]),
                                                       float(df2[1:]['pressure_set_1'][temp + 3])
                                                   ])
except ValueError:
    print("successfully changed NaN values")
# Out:
# C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\IPython\core\interactiveshell.py:3417: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# successfully changed NaN values

# %%
df2[1:]['relative_humidity_set_1'][pd.isnull(df2[1:]['relative_humidity_set_1'])==True]
# Out:
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
#        ...
# 7917    NaN
# 7918    NaN
# 7919    NaN
# 7920    NaN
# 7921    NaN
# Name: relative_humidity_set_1, Length: 1539, dtype: object

# %%
try:
    while list(df2[1:]['relative_humidity_set_1']).index(np.NaN):
        temp=list(df2[1:]['relative_humidity_set_1']).index(np.NaN)
        df2[1:]['relative_humidity_set_1'][temp+1]=np.nanmean([
                                                       float(df2[1:]['relative_humidity_set_1'][temp-1]),
                                                       float(df2[1:]['relative_humidity_set_1'][temp]),
                                                       float(df2[1:]['relative_humidity_set_1'][temp + 2]),
                                                       float(df2[1:]['relative_humidity_set_1'][temp + 3])
                                                   ])
except ValueError:
    print("successfully changed NaN values")
# Out:
# C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\IPython\core\interactiveshell.py:3417: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# successfully changed NaN values

# %%
df2[1:]['wind_speed_set_1'][pd.isnull(df2[1:]['wind_speed_set_1'])==True]
# Out:
# Series([], Name: wind_speed_set_1, dtype: object)

# %%
df2[1:]['wind_direction_set_1'][pd.isnull(df2[1:]['wind_direction_set_1'])==True]
# Out:
# 18      NaN
# 22      NaN
# 23      NaN
# 25      NaN
# 113     NaN
#        ...
# 7893    NaN
# 7894    NaN
# 7895    NaN
# 7905    NaN
# 7908    NaN
# Name: wind_direction_set_1, Length: 620, dtype: object

# %%
try:
    while list(df2[1:]['wind_direction_set_1']).index(np.NaN):
        temp=list(df2[1:]['wind_direction_set_1']).index(np.NaN)
        df2[1:]['wind_direction_set_1'][temp+1]=np.nanmean([
                                                       float(df2[1:]['wind_direction_set_1'][temp-1]),
                                                       float(df2[1:]['wind_direction_set_1'][temp]),
#                                                        float(df2[1:]['wind_direction_set_1'][temp + 2]),
#                                                        float(df2[1:]['wind_direction_set_1'][temp + 3])
                                                   ])
except ValueError:
    print("successfully changed NaN values")
# Out:
# successfully changed NaN values

# %%
df2[1:]['dew_point_temperature_set_1d'][pd.isnull(df2[1:]['dew_point_temperature_set_1d'])==True]
# Out:
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
#        ...
# 7917    NaN
# 7918    NaN
# 7919    NaN
# 7920    NaN
# 7921    NaN
# Name: dew_point_temperature_set_1d, Length: 1539, dtype: object

# %%
try:
    while list(df2[1:]['dew_point_temperature_set_1d']).index(np.NaN):
        temp=list(df2[1:]['dew_point_temperature_set_1d']).index(np.NaN)
        df2[1:]['dew_point_temperature_set_1d'][temp+1]=np.nanmean([
                                                       float(df2[1:]['dew_point_temperature_set_1d'][temp-1]),
                                                       float(df2[1:]['dew_point_temperature_set_1d'][temp]),
                                                       float(df2[1:]['dew_point_temperature_set_1d'][temp + 2]),
                                                       float(df2[1:]['dew_point_temperature_set_1d'][temp + 3])
                                                   ])
except ValueError:
    print("successfully changed NaN values")
# Out:
# C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\IPython\core\interactiveshell.py:3417: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# successfully changed NaN values

# %%
df1 = df1[['Latitude','Longitude', 'Sample Measurement', 'Date Local', 'Time Local']]
df1
# Out:
#           Latitude  Longitude  Sample Measurement  Date Local Time Local
# 0        30.497478 -87.880258               0.030  2015-03-01      01:00
# 1        30.497478 -87.880258               0.026  2015-03-01      03:00
# 2        30.497478 -87.880258               0.028  2015-03-01      04:00
# 3        30.497478 -87.880258               0.028  2015-03-01      05:00
# 4        30.497478 -87.880258               0.026  2015-03-01      06:00
# ...            ...        ...                 ...         ...        ...
# 9038438  18.177939 -65.915482               0.021  2015-12-31      19:00
# 9038439  18.177939 -65.915482               0.020  2015-12-31      20:00
# 9038440  18.177939 -65.915482               0.023  2015-12-31      21:00
# 9038441  18.177939 -65.915482               0.019  2015-12-31      22:00
# 9038442  18.177939 -65.915482               0.022  2015-12-31      23:00
#
# [9038443 rows x 5 columns]

# %%
del df2['precip_accum_set_1']
del df2['wind_chill_set_1d']
del df2['wind_cardinal_direction_set_1d']
del df2['heat_index_set_1d']
del df2['sea_level_pressure_set_1d']
del df2['wet_bulb_temperature_set_1d']
del df2['altimeter_set_1d']
df2
# Out:
#      Station_ID             Date_Time pressure_set_1 air_temp_set_1  \
# 0           NaN                   NaN           INHG     Fahrenheit
# 1         AN142  01/01/2015 02:00 EST          29.47          32.92
# 2         AN142  01/01/2015 03:00 EST          29.47          32.02
# 3         AN142  01/01/2015 04:00 EST          29.47          31.66
# 4         AN142  01/01/2015 05:00 EST          29.44          31.12
# ...         ...                   ...            ...            ...
# 7929      AN142  12/31/2015 20:00 EST          16.18          50.92
# 7930      AN142  12/31/2015 21:00 EST          16.06          50.02
# 7931      AN142  12/31/2015 22:00 EST          15.98          49.12
# 7932      AN142  12/31/2015 23:00 EST          15.86          47.86
# 7933      AN142  01/01/2016 00:00 EST          15.86          47.86
#
#      relative_humidity_set_1 wind_speed_set_1 wind_direction_set_1  \
# 0                          %       Miles/hour              Degrees
# ...

# %%
df1['Date_Time'] = df1['Date Local'] + ' ' + df1['Time Local'] + ' ' + 'EST'
df1
# Out:
#           Latitude  Longitude  Sample Measurement  Date Local Time Local  \
# 0        30.497478 -87.880258               0.030  2015-03-01      01:00
# 1        30.497478 -87.880258               0.026  2015-03-01      03:00
# 2        30.497478 -87.880258               0.028  2015-03-01      04:00
# 3        30.497478 -87.880258               0.028  2015-03-01      05:00
# 4        30.497478 -87.880258               0.026  2015-03-01      06:00
# ...            ...        ...                 ...         ...        ...
# 9038438  18.177939 -65.915482               0.021  2015-12-31      19:00
# 9038439  18.177939 -65.915482               0.020  2015-12-31      20:00
# 9038440  18.177939 -65.915482               0.023  2015-12-31      21:00
# 9038441  18.177939 -65.915482               0.019  2015-12-31      22:00
# 9038442  18.177939 -65.915482               0.022  2015-12-31      23:00
#
#                     Date_Time
# 0        2015-03-01 01:00 EST
# ...

# %%
del df1['Date Local']
del df1['Time Local']
df1
# Out:
#           Latitude  Longitude  Sample Measurement             Date_Time
# 0        30.497478 -87.880258               0.030  2015-03-01 01:00 EST
# 1        30.497478 -87.880258               0.026  2015-03-01 03:00 EST
# 2        30.497478 -87.880258               0.028  2015-03-01 04:00 EST
# 3        30.497478 -87.880258               0.028  2015-03-01 05:00 EST
# 4        30.497478 -87.880258               0.026  2015-03-01 06:00 EST
# ...            ...        ...                 ...                   ...
# 9038438  18.177939 -65.915482               0.021  2015-12-31 19:00 EST
# 9038439  18.177939 -65.915482               0.020  2015-12-31 20:00 EST
# 9038440  18.177939 -65.915482               0.023  2015-12-31 21:00 EST
# 9038441  18.177939 -65.915482               0.019  2015-12-31 22:00 EST
# 9038442  18.177939 -65.915482               0.022  2015-12-31 23:00 EST
#
# [9038443 rows x 4 columns]

# %%
def format_string(string):
    temp = string[6:10] + '/' + string[:5] + string[10:]
    return temp
df2['Date_Time'] = df2['Date_Time'].astype(str).apply(format_string)
df2
# Out:
#      Station_ID             Date_Time pressure_set_1 air_temp_set_1  \
# 0           NaN                  /nan           INHG     Fahrenheit
# 1         AN142  2015/01/01 02:00 EST          29.47          32.92
# 2         AN142  2015/01/01 03:00 EST          29.47          32.02
# 3         AN142  2015/01/01 04:00 EST          29.47          31.66
# 4         AN142  2015/01/01 05:00 EST          29.44          31.12
# ...         ...                   ...            ...            ...
# 7929      AN142  2015/12/31 20:00 EST          16.18          50.92
# 7930      AN142  2015/12/31 21:00 EST          16.06          50.02
# 7931      AN142  2015/12/31 22:00 EST          15.98          49.12
# 7932      AN142  2015/12/31 23:00 EST          15.86          47.86
# 7933      AN142  2016/01/01 00:00 EST          15.86          47.86
#
#      relative_humidity_set_1 wind_speed_set_1 wind_direction_set_1  \
# 0                          %       Miles/hour              Degrees
# ...

# %%
df1[:]['Date_Time'] = df1.iloc[:]['Date_Time'].str.replace('-', '/')
df1
# Out:
#           Latitude  Longitude  Sample Measurement             Date_Time
# 0        30.497478 -87.880258               0.030  2015/03/01 01:00 EST
# 1        30.497478 -87.880258               0.026  2015/03/01 03:00 EST
# 2        30.497478 -87.880258               0.028  2015/03/01 04:00 EST
# 3        30.497478 -87.880258               0.028  2015/03/01 05:00 EST
# 4        30.497478 -87.880258               0.026  2015/03/01 06:00 EST
# ...            ...        ...                 ...                   ...
# 9038438  18.177939 -65.915482               0.021  2015/12/31 19:00 EST
# 9038439  18.177939 -65.915482               0.020  2015/12/31 20:00 EST
# 9038440  18.177939 -65.915482               0.023  2015/12/31 21:00 EST
# 9038441  18.177939 -65.915482               0.019  2015/12/31 22:00 EST
# 9038442  18.177939 -65.915482               0.022  2015/12/31 23:00 EST
#
# [9038443 rows x 4 columns]

# %%
df = df2.merge(df1, on='Date_Time')
df
# Out:
#         Station_ID             Date_Time pressure_set_1 air_temp_set_1  \
# 0            AN142  2015/01/01 02:00 EST          29.47          32.92
# 1            AN142  2015/01/01 02:00 EST          29.47          32.92
# 2            AN142  2015/01/01 02:00 EST          29.47          32.92
# 3            AN142  2015/01/01 02:00 EST          29.47          32.92
# 4            AN142  2015/01/01 02:00 EST          29.47          32.92
# ...            ...                   ...            ...            ...
# 2151637      AN142  2015/12/31 23:00 EST          15.86          47.86
# 2151638      AN142  2015/12/31 23:00 EST          15.86          47.86
# 2151639      AN142  2015/12/31 23:00 EST          15.86          47.86
# 2151640      AN142  2015/12/31 23:00 EST          15.86          47.86
# 2151641      AN142  2015/12/31 23:00 EST          15.86          47.86
#
#         relative_humidity_set_1 wind_speed_set_1 wind_direction_set_1  \
# ...

# %%
DF = df.iloc[:, 2:]
DF
# Out:
#         pressure_set_1 air_temp_set_1 relative_humidity_set_1  \
# 0                29.47          32.92                    37.0
# 1                29.47          32.92                    37.0
# 2                29.47          32.92                    37.0
# 3                29.47          32.92                    37.0
# 4                29.47          32.92                    37.0
# ...                ...            ...                     ...
# 2151637          15.86          47.86                    88.0
# 2151638          15.86          47.86                    88.0
# 2151639          15.86          47.86                    88.0
# 2151640          15.86          47.86                    88.0
# 2151641          15.86          47.86                    88.0
#
#         wind_speed_set_1 wind_direction_set_1 dew_point_temperature_set_1d  \
# 0                   0.67                292.0                         9.26
# ...

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(DF)
cols = DF.columns
DF_normalized = pd.DataFrame(np_scaled, columns = cols)
DF_normalized
# Out:
#          pressure_set_1  air_temp_set_1  relative_humidity_set_1  \
# 0              0.980548        0.298667                 0.367347
# 1              0.980548        0.298667                 0.367347
# 2              0.980548        0.298667                 0.367347
# 3              0.980548        0.298667                 0.367347
# 4              0.980548        0.298667                 0.367347
# ...                 ...             ...                      ...
# 2151637        0.000000        0.520000                 0.887755
# 2151638        0.000000        0.520000                 0.887755
# 2151639        0.000000        0.520000                 0.887755
# 2151640        0.000000        0.520000                 0.887755
# 2151641        0.000000        0.520000                 0.887755
#
#          wind_speed_set_1  wind_direction_set_1  dew_point_temperature_set_1d  \
# 0                0.115120              0.813370                      0.457692
# ...

# %%
FINAL = DF_normalized.iloc[:10000]
FINAL
# Out:
#       pressure_set_1  air_temp_set_1  relative_humidity_set_1  \
# 0           0.980548        0.298667                 0.367347
# 1           0.980548        0.298667                 0.367347
# 2           0.980548        0.298667                 0.367347
# 3           0.980548        0.298667                 0.367347
# 4           0.980548        0.298667                 0.367347
# ...              ...             ...                      ...
# 9995        0.974063        0.626667                 0.275510
# 9996        0.974063        0.626667                 0.275510
# 9997        0.974063        0.626667                 0.275510
# 9998        0.974063        0.626667                 0.275510
# 9999        0.974063        0.626667                 0.275510
#
#       wind_speed_set_1  wind_direction_set_1  dew_point_temperature_set_1d  \
# 0              0.11512              0.813370                      0.457692
# ...

# %%
x = FINAL[['pressure_set_1','air_temp_set_1','relative_humidity_set_1','wind_speed_set_1','wind_direction_set_1','dew_point_temperature_set_1d','Latitude','Longitude']]
x
# Out:
#       pressure_set_1  air_temp_set_1  relative_humidity_set_1  \
# 0           0.980548        0.298667                 0.367347
# 1           0.980548        0.298667                 0.367347
# 2           0.980548        0.298667                 0.367347
# 3           0.980548        0.298667                 0.367347
# 4           0.980548        0.298667                 0.367347
# ...              ...             ...                      ...
# 9995        0.974063        0.626667                 0.275510
# 9996        0.974063        0.626667                 0.275510
# 9997        0.974063        0.626667                 0.275510
# 9998        0.974063        0.626667                 0.275510
# 9999        0.974063        0.626667                 0.275510
#
#       wind_speed_set_1  wind_direction_set_1  dew_point_temperature_set_1d  \
# 0              0.11512              0.813370                      0.457692
# ...

# %%
y = FINAL[['Sample Measurement']]
y
# Out:
#       Sample Measurement
# 0               0.165049
# 1               0.359223
# 2               0.058252
# 3               0.485437
# 4               0.320388
# ...                  ...
# 9995            0.339806
# 9996            0.320388
# 9997            0.349515
# 9998            0.320388
# 9999            0.368932
#
# [10000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.4,random_state = 101)

# %%
x_train
# Out:
#       pressure_set_1  air_temp_set_1  relative_humidity_set_1  \
# 9252        0.974063        0.626667                 0.275510
# 2683        0.978386        0.272000                 0.367347
# 1380        0.980548        0.285333                 0.367347
# 1027        0.980548        0.285333                 0.367347
# 4671        0.980548        0.253333                 0.510204
# ...              ...             ...                      ...
# 599         0.980548        0.298667                 0.367347
# 5695        0.980548        0.269333                 0.576531
# 8006        0.980548        0.538667                 0.387755
# 1361        0.980548        0.285333                 0.367347
# 1547        0.980548        0.280000                 0.367347
#
#       wind_speed_set_1  wind_direction_set_1  dew_point_temperature_set_1d  \
# 9252          0.384880              0.779944                      0.566603
# ...

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(x_test)
predictions
# Out:
# array([[0.31149748],
#        [0.3437994 ],
#        [0.35467723],
#        ...,
#        [0.36570523],
#        [0.17540934],
#        [0.27757682]])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test,predictions)
# Out:
# 0.07553755726841209

# %%
np.sqrt(metrics.mean_squared_error(y_test,predictions))
# Out:
# 0.0954805542358035
